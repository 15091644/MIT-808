# %%
_debug=False

# %% [markdown]
# # Import Data

# %%
# Change working directory
import os
cwd = os.getcwd ()
fd = 'C:/Py/PyProj/2022Env387MIT808/GitHub/MIT-808/data/raw/' #ToDo how to make this generic to GitHub folders structure?
os.chdir(fd)
print(cwd, 'to', os.getcwd ())
# Out:
# C:\Py\PyProj\2022_Notebooks to C:\Py\PyProj\2022Env387MIT808\GitHub\MIT-808\data\raw

# %%
# Read source Excel
import pandas as pd
fn = 'query-sdg-full_20220312_1550.csv'    # 380Mb file
#fn = 'query-sdg-full_20220312_92k.csv'    #  98Mb file
# Description and instrumenttag
df = pd.read_csv(fn, sep='|', header=0)

# %%
df.head(2)
# Out:
#    ptr_id  articletype_id sdg_lst                  authors  \
# 0      13            13.0   14, 2  {"Jansen, Jonathan D."}
# 1      14            14.0       2  {"Jansen, Jonathan D."}
#
#                                                title  \
# 0  Autonomy and accountability in the regulation ...
# 1                           Intellectuals under fire
#
#                                              content  \
# 0  This article examines the struggles of the Sou...
# 1  Looks at the status of intellectuals in South ...
#
#                                             keywords  institution_id
# 0  {Autonomy,Learning,Performance,Teaching,"Gover...               1
# 1  {"Cultural policy",Democracy,"Political system...               1

# %%
n=1
print(df.title[n])
print(df.content[n])
print('\n')
print(df.keywords[n])
# Out:
# Intellectuals under fire
# Looks at the status of intellectuals in South Africa ten years after democracy was established in the country. Direction of democracy in the country; Concerns about the policies of the government and its response to criticism from intellectuals.
#
#
# {"Cultural policy",Democracy,"Political systems",Intellectuals,Politics,"Cultural policy",Democracy,"Political systems",Intellectuals,Politics,"Cultural policy",Democracy,"Political systems",Intellectuals,Politics,"Cultural policy",Democracy,"Political systems",Intellectuals,Politics,"Cultural policy",Democracy,"Political systems",Intellectuals,Politics,"Cultural policy",Democracy,"Political systems",Intellectuals,Politics,"Cultural policy",Democracy,"Political systems",Intellectuals,Politics,"Cultural policy",Democracy,"Political systems",Intellectuals,Politics,"Cultural policy",Democracy,"Political systems",Intellectuals,Politics,"Cultural policy",Democracy,"Political systems",Intellectuals,Politics,"Cultural policy",Democracy,"Political systems",Intellectuals,Politics,"Cultural policy",Democracy,"Political systems",Intellectuals,Politics,"Cultural policy",Democracy,"Political systems",Intellectuals,Politics,"Cultural policy",Democracy,"Political systems",Intellectuals,Politics,"Cultural policy",Democracy,"Political systems",Intellectuals,Politics,"Cultural policy",Democracy,"Political systems",Intellectuals,Politics,"Cultural policy",Democracy,"Political systems",Intellectuals,Politics,"Cultural policy",Democracy,"Political systems",Intellectuals,Politics,"Cultural policy",Democracy,"Political systems",Intellectuals,Politics,"Cultural policy",Democracy,"Political systems",Intellectuals,Politics,"Cultural policy",Democracy,"Political systems",Intellectuals,Politics,"Cultural policy",Democracy,"Political systems",Intellectuals,Politics,"Cultural policy",Democracy,"Political systems",Intellectuals,Politics,"Cultural policy",Democracy,"Political systems",Intellectuals,Politics,"Cultural policy",Democracy,"Political systems",Intellectuals,Politics,"Cultural policy",Democracy,"Political systems",Intellectuals,Politics,"Cultural policy",Democracy,"Political systems",Intellectuals,Politics,"Cultural policy",Democracy,"Political systems",Intellectuals,Politics}

# %% [markdown]
# # Evaluate Data Quality

# %%
# Unique ID
df.ptr_id.is_unique
# Out:
# True

# %%
# Unique ID
df.articletype_id.is_unique
# Out:
# True

# %%
#Report nulls
null_columns=df.columns[df.isnull().any()]
print('Columns with nulls:\n', df[null_columns].isnull().sum())
for col in null_columns:
    df[col]=df[col].fillna(0)
# Out:
# Columns with nulls:
#  articletype_id     1
# sdg_lst            1
# content           23
# dtype: int64

# %%
null_columns=df.columns[df.isnull().any()]
print('Columns with nulls:\n', df[null_columns].isnull().sum())
# Out:
# Columns with nulls:
#  Series([], dtype: float64)

# %%
#check for NaN
df1 = df[df.isna().any(axis=1)]
df1.shape
#del df1
# Out:
# (0, 8)

# %%
# Check sum: ptr_id should equal articletype_id
print('count mismatchees:', df.loc[ (df.ptr_id != df.articletype_id)].shape)
print(df.loc[ (df.ptr_id != df.articletype_id)])
if _debug:
    print('shape', df.shape)
    print('drop', df.drop(df[ (df.ptr_id != df.articletype_id) ].index, inplace = True))
df.drop(df[ (df.ptr_id != df.articletype_id) ].index, inplace = True)
# Out:
# count mismatchees: (1, 8)
#         ptr_id  articletype_id sdg_lst      authors             title  \
# 208806  342219             0.0       0  {"齋藤, 久美子"}  黨錮と學問 : とくに何休の場合
#
#                                                   content keywords  \
# 208806  黒人奴隷制に基づくタバコ・プランテーションの展開をみたメリーランド植民地とヴァジニア植民地は...   {NULL}
#
#         institution_id
# 208806              38

# %%
df.shape
# Out:
# (208806, 8)

# %% [markdown]
# ### Clean up keywords feature to have unique phrases.

# %%
kw=df.keywords

# %%
if _debug:
    print(kw[0])

# %%
# strip left of '{'
left=kw.str.split('{').str[1]
# strip right of '}'
right=left.str.split('}').str[0]
kw=right.str.replace('"', "")

# %%
if _debug:
    print(kw[0])

# %%
# Convert delimited strings into lists; and keep unique strings. 
list_all = kw.str.split(',')
list_unique = []
for i, v in enumerate(list_all):
    list_unique.append(list(set(list_all[i])))

# %%
if _debug:
    n=1
    print(list_unique[n])
    print(list_all[n])
    print(len(list_unique))

# %%
df['unique_keywords']=list_unique
del kw, list_all, list_unique

# %%
df.head(1).T
# Out:
#                                                                  0
# ptr_id                                                          13
# articletype_id                                                13.0
# sdg_lst                                                      14, 2
# authors                                    {"Jansen, Jonathan D."}
# title            Autonomy and accountability in the regulation ...
# content          This article examines the struggles of the Sou...
# keywords         {Autonomy,Learning,Performance,Teaching,"Gover...
# institution_id                                                   1
# unique_keywords  [Educational policy, Democracy, Accountability...

# %% [markdown]
# ### Convert sdg text into lists

# %%
sdg=df.sdg_lst

# %%
# list of strings
list_all = sdg.str.split(',')

#ToDo better code needed here
# list of integers 
n=0
list_int = []
for i, v1 in enumerate(list_all):
    lst = []
    
    try:
        for j, v2 in enumerate(list_all[i]):
            lst.append(int(v2))
        n=+1
    except:
        print('skip: ', i, n, list_all[i])
    
    list_int.append(lst)  

if _debug:
    print(list_all[0])
    print(list_int[0])
    
#append to df
df['sdg_ints']=list_int
del sdg, list_all, list_int

# %%
df.T
# Out:
#                                                             0       \
# ptr_id                                                          13
# articletype_id                                                13.0
# sdg_lst                                                      14, 2
# authors                                    {"Jansen, Jonathan D."}
# title            Autonomy and accountability in the regulation ...
# content          This article examines the struggles of the Sou...
# keywords         {Autonomy,Learning,Performance,Teaching,"Gover...
# institution_id                                                   1
# unique_keywords  [Educational policy, Democracy, Accountability...
# sdg_ints                                                   [14, 2]
#
#                                                             1       \
# ptr_id                                                          14
# articletype_id                                                14.0
# sdg_lst                                                          2
# authors                                    {"Jansen, Jonathan D."}
# title                                     Intellectuals under fire
# content          Looks at the status of intellectuals in South ...
# keywords         {"Cultural policy",Democracy,"Political system...
# institution_id                                                   1
# unique_keywords  [Political systems, Intellectuals, Democracy, ...
# sdg_ints                                                       [2]
#
#                                                             2       \
# ptr_id                                                          16
# articletype_id                                                16.0
# sdg_lst                                                          2
# authors                                    {"Jansen, Jonathan D."}
# title            Mode 2 knowledge and institutional life: takin...
# content          This paper examines the response of a black un...
# keywords         {"Higher education","Information technology","...
# institution_id                                                   1
# unique_keywords  [Knowledge theory, Institutional life, Mode 2 ...
# sdg_ints                                                       [2]
#
#                                                             3       \
# ptr_id                                                          17
# articletype_id                                                17.0
# sdg_lst                                                      14, 1
# authors                                    {"Jansen, Jonathan D."}
# title            Political symbolism as policy craft : explaini...
# content          The policy literature in developing countries ...
# keywords         {Apartheid,"Educational change","Educational p...
# institution_id                                                   1
# unique_keywords  [Educational policy, Apartheid, Educational ch...
# sdg_ints                                                   [14, 1]
#
#                                                             4       \
# ptr_id                                                          18
# articletype_id                                                18.0
# sdg_lst                                                         14
# authors                                    {"Jansen, Jonathan D."}
# title            School curriculum since apartheid : intersecti...
# content          In the wake of South Africa's first non-racial...
# keywords         {"Curriculum development","Educational policy"...
# institution_id                                                   1
# unique_keywords  [Educational policy, Educational change, Polit...
# sdg_ints                                                      [14]
#
#                                                             5       \
# ptr_id                                                          19
# articletype_id                                                19.0
# sdg_lst                                                         14
# authors                                    {"Jansen, Jonathan D."}
# title            Curriculum reform in South Africa : a critical...
# content          Provides an analysis of outcomes-based educati...
# keywords         {"Outcomes based education","Curriculum planni...
# institution_id                                                   1
# unique_keywords  [Educational policy, Educational change, Curri...
# sdg_ints                                                      [14]
#
#                                                             6       \
# ptr_id                                                          20
# articletype_id                                                20.0
# sdg_lst                                                         14
# authors                                    {"Jansen, Jonathan D."}
# title            State and curriculum in the transition to soci...
# content          Uses a case study of curriculum innovation in ...
# keywords         {"Curriculum development","Educational change"...
# institution_id                                                   1
# unique_keywords  [Educational policy, Educational change, Polit...
# sdg_ints                                                      [14]
#
#                                                             7       \
# ptr_id                                                          21
# articletype_id                                                21.0
# sdg_lst                                                          7
# authors                                                  {Unknown}
# title                                   Herbert Baker,  F.R.I.B.A.
# content          Article about Mr. Herbert Baker, whose work an...
# keywords         {"Baker, Herbert, Sir, 1862-1946","South Afric...
# institution_id                                                   1
# unique_keywords  [Union Buildings, F.R.I.B.A.,  Sir, Rhodes, Ro...
# sdg_ints                                                       [7]
#
#                                                             8       \
# ptr_id                                                          22
# articletype_id                                                22.0
# sdg_lst                                                          7
# authors                         {"Baker, Herbert, Sir, 1862-1946"}
# title                                      Plea for English Gothic
# content          In response to letters discussing the merits o...
# keywords         {"English Gothic architecture","South African ...
# institution_id                                                   1
# unique_keywords  [Ruskin,  Edward W., Church architecture, Rhod...
# sdg_ints                                                       [7]
#
#                                                             9       ...  \
# ptr_id                                                          24  ...
# articletype_id                                                24.0  ...
# sdg_lst                                                          7  ...
# authors                         {"Baker, Herbert, Sir, 1862-1946"}  ...
# title            Two unrealized visions: Sir Herbert Baker reco...  ...
# content          In this article, sir Herbert Baker recounts th...  ...
# keywords         {"Smuts, Jan Christiaan, 1870-1950","Murray, C...  ...
# institution_id                                                   1  ...
# unique_keywords  [Union Buildings, Rhodes, Smuts, Wren,  Charle...  ...
# sdg_ints                                                       [7]  ...
#
#                                                             208796  \
# ptr_id                                                      229323
# articletype_id                                            229323.0
# sdg_lst                                                         15
# authors          {"Ellingson, Benjamin M","Bendszus, Martin","S...
# title            Emerging techniques and technologies in brain ...
# content          The purpose of this report is to describe the ...
# keywords         {Humans,Glioma,"Brain Neoplasms","Positron-Emi...
# institution_id                                                  34
# unique_keywords  [4.2 Evaluation of markers and technologies, M...
# sdg_ints                                                      [15]
#
#                                                             208797  \
# ptr_id                                                      229324
# articletype_id                                            229324.0
# sdg_lst                                                         15
# authors          {"Dunn, Sarah E","Li, Hua","Cardone, Giovanni"...
# title            Three-dimensional structure of victorivirus Hv...
# content          Double-stranded (ds)RNA fungal viruses are cur...
# keywords         {Totivirus,Virion,Helminthosporium,"RNA Replic...
# institution_id                                                  34
# unique_keywords  [RNA, Virion, Helminthosporium, Double-Strande...
# sdg_ints                                                      [15]
#
#                                                             208798  \
# ptr_id                                                      229325
# articletype_id                                            229325.0
# sdg_lst                                                         15
# authors          {"Li, Zhihai","Yan, Xiaodong","Yu, Hai","Wang,...
# title            The C-Terminal Arm of the Human Papillomavirus...
# content          Cervical cancer is the second most prevalent m...
# keywords         {"Cell Line",Tumor,Humans,Papillomaviridae,"On...
# institution_id                                                  34
# unique_keywords  [Host-Pathogen Interactions, Molecular Dynamic...
# sdg_ints                                                      [15]
#
#                                                             208799  \
# ptr_id                                                      229326
# articletype_id                                            229326.0
# sdg_lst                                                      16, 5
# authors          {"Haack, Daniel B","Yan, Xiaodong","Zhang, Che...
# title            Cryo-EM Structures of a Group II Intron Revers...
# content          Group II introns are a class of retroelements ...
# keywords         {Spliceosomes,"Escherichia coli","RNA-Directed...
# institution_id                                                  34
# unique_keywords  [RNA, Protein Structure, ribozyme, retroelemen...
# sdg_ints                                                   [16, 5]
#
#                                                             208800  \
# ptr_id                                                      229327
# articletype_id                                            229327.0
# sdg_lst                                                         15
# authors          {"Xu, Longfa","Zheng, Qingbing","Li, Shaowei",...
# title            Atomic structures of Coxsackievirus A6 and its...
# content          Coxsackievirus A6 (CVA6) has recently emerged ...
# keywords         {Animals,Humans,Mice,"Enterovirus A",Human,Cap...
# institution_id                                                  34
# unique_keywords  [Humans, Epitopes, Animals, Enterovirus A, Vir...
# sdg_ints                                                      [15]
#
#                                                             208801  \
# ptr_id                                                      229328
# articletype_id                                            229328.0
# sdg_lst                                                          2
# authors                       {"Amin, Kemi","Taylor, Anneliese S"}
# title                Elevator Pitch Exercise Template and Examples
# content          Use this elevator pitch template for exercises...
# keywords         {communications,library,bioinformatician,"scho...
# institution_id                                                  34
# unique_keywords  [open access, scholarly communication, library...
# sdg_ints                                                       [2]
#
#                                                             208802  \
# ptr_id                                                      229329
# articletype_id                                            229329.0
# sdg_lst                                                          1
# authors                         {"Yang, Su-Fen","Arnold, Barry C"}
# title            A simple approach for monitoring business serv...
# content          Control charts are effective tools for signal ...
# keywords         {Models,Statistical,Algorithms,Time,Commerce,"...
# institution_id                                                  34
# unique_keywords  [Statistical, Time, Commerce, Models, General ...
# sdg_ints                                                       [1]
#
#                                                             208803  \
# ptr_id                                                      229330
# articletype_id                                            229330.0
# sdg_lst                                                         16
# authors          {"Stein, Hans Henrik","Casas, Gloria Amparo","...
# title            Nutritional value of high fiber co-products fr...
# content          High fiber co-products from the copra and palm...
# keywords         {"Copra expellers","Copra meal","Palm kernel e...
# institution_id                                                  34
# unique_keywords  [Copra expellers, Palm kernel expellers, Palm ...
# sdg_ints                                                      [16]
#
#                                                             208804  \
# ptr_id                                                      229331
# articletype_id                                            229331.0
# sdg_lst                                                    1, 7, 8
# authors                        {"Bromfield, Heather","Moore, Eli"}
# title            Unfair Shares: Racial Disparities and the Regi...
# content          This report reveals that in the San Francisco ...
# keywords         {"Bay Area allocations",methods,terminology,pe...
# institution_id                                                  34
# unique_keywords  [historical, methods, housing crisis, regional...
# sdg_ints                                                 [1, 7, 8]
#
#                                                             208805
# ptr_id                                                      229332
# articletype_id                                            229332.0
# sdg_lst                                                          7
# authors                                {"Ekman, Annaleigh Yahata"}
# title            Meeting Travel Needs: Becoming Reacquainted wi...
# content          Our current examples of transportation needs a...
# keywords         {needs,travel,behavior,community,"urban planni...
# institution_id                                                  34
# unique_keywords  [survey, travel, needs, research, community, u...
# sdg_ints                                                       [7]
#
# [10 rows x 208806 columns]
